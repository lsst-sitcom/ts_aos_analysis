# %%
from lsst.summit.utils import (
    ConsDbClient,
    getAirmassSeeingCorrection,
    getBandpassSeeingCorrection,
)

# %%
getBandpassSeeingCorrection("z_03")
# Out:
# 1.1163680899291244

# %%
getBandpassSeeingCorrection("i_39")
# Out:
# 1.0854961781152848

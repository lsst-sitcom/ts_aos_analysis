# %%
# Times Square Parameters
day_obs = 20260406

# %%
from lsst.daf.butler import Butler

# %%
butler = Butler('embargo', instrument='LSSTCam')

# %%
print(f'Available AOS Collections processed overnight at USDF for day_obs: {day_obs}')
print(butler.registry.queryCollections(f'u/brycek/aos_cwfs_nightly/wep_v16_9_0/donut_viz_v3_6_1/{day_obs}'))
# Out:
# Available AOS Collections processed overnight at USDF for day_obs: 20260406
# ['u/brycek/aos_cwfs_nightly/wep_v16_9_0/donut_viz_v3_6_1/20260406']
